# %%
import os
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("data_3.xlsx")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.read_excel("data_3.xlsx")
#       2 df.head()
#
# File ~\anacond3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
# ...

# %% [markdown]
# **A1. Az adathalmaz megismerése, a benne szereplő attribútumok bemutatása és általános jellemzése**
#
# - Az adathalmaz 210 mért búzaszem adatait tartalmazza.
# - Három búzafajtát vizsgál: Kama, Rosa és Canadian. Fajtánként 70-70 szem.
#
# Megj.: A magokat puha röntgennel fényképezték és a röntgen alapján számítógéppel számolták a méreteiket.
#
# **Attribútumok (magok mért, számított adatai)**
# 1. **area** - képben elfoglalt terület
# 2. **perimeter** - kerülete
# 3. **compactness** - tömörség (képlete: C = 4*pi*A/P^2)
# 4. **length** - hossza
# 5. **width** - szélessége
# 6. **assymetry** - mennyire asszimetrikus
# 7. **groove length** - felszíni barázda hossza
# 8. **class** - fajta (Kama, Rosa vagy Canadian)
#
# Minden jellemző folytonos, valós értékű változó, a „class” pedig kategóriát ad (három lehetséges értéket).

# %% [markdown]
# **A2. Előfeldolgozás, adattisztítás, pl. hiányzó adatok vagy extrém értékek feltérképezése, illetve kezelése, adatkonverzió**
